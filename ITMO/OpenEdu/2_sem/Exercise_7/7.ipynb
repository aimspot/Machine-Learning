# %% [markdown]
# # 1

# %%
import cv2

# %%
img = cv2.imread('/Users/misha/Desktop/GitHub/Machine-Learning/ITMO/OpenEdu/2_sem/Exercise_7/photo/1.jpeg')

# %%
print(f'Width:{img.shape[1]}')
print(f'Height:{img.shape[0]}')
# Out:
# Width:5758
# Height:3839

# %%
B,G,R = img[1937,2893]
print(R,',',G,',', B)
# Out:
# 97 , 99 , 2

# %% [markdown]
# # 2

# %%
img = cv2.imread('/Users/misha/Desktop/GitHub/Machine-Learning/ITMO/OpenEdu/2_sem/Exercise_7/photo/2.jpeg')
#image_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

sub_matrix = img[1470:2390, 2670:3370]

print("Sub-matrix shape:", sub_matrix.shape)
cv2.imwrite("photo/s.jpg", sub_matrix)
# Out:
# Sub-matrix shape: (920, 700, 3)
# True

# %% [markdown]
# # 3

# %%
# !pip install pip==21.3.1
# Out:
# Collecting pip==21.3.1
#   Using cached pip-21.3.1-py3-none-any.whl (1.7 MB)
# Installing collected packages: pip
#   Attempting uninstall: pip
#     Found existing installation: pip 23.1.2
#     Uninstalling pip-23.1.2:
#       Successfully uninstalled pip-23.1.2
# Successfully installed pip-21.3.1

# %%
# !pip3 install opencv-python==4.4.0.42
# Out:
# Collecting opencv-python==4.4.0.42
#   Downloading opencv_python-4.4.0.42-cp37-cp37m-macosx_10_13_x86_64.whl (52.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.2/52.2 MB 6.5 MB/s eta 0:00:0000:0100:01m
# Requirement already satisfied: numpy>=1.14.5 in /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages (from opencv-python==4.4.0.42) (1.21.6)
# Installing collected packages: opencv-python
#   Attempting uninstall: opencv-python
#     Found existing installation: opencv-python 4.6.0.66
#     Uninstalling opencv-python-4.6.0.66:
#       Successfully uninstalled opencv-python-4.6.0.66
# Successfully installed opencv-python-4.4.0.42

# %%
# Reading image with OpenCV
images_path = "photo/"
image_2_name = "markus-winkler-wvii1ayGs3A-unsplash.jpg"
image_2 = cv2.imread(images_path + image_2_name)

# Converting image from bgr to rgb format
image_2 = cv2.cvtColor(image_2, cv2.COLOR_BGR2RGB)

# Getting basic image info
height_2, width_2, color_channels_2 = image_2.shape
#print("Image 2 resolution is {}x{}".format(width_2, height_2))

# Calculating proportionality coefficient
k = float(width_2) / height_2
print("Aspect ratio of image is: {}".format(k))

# Compressing image proportionally
new_width = 820
new_height = int(new_width / k)
print("New image height is {}".format(new_height))
dim = (new_width, new_height)
image_2_resized = cv2.resize(image_2, dim, interpolation = cv2.INTER_AREA)
plt.imshow(image_2_resized)
plt.show()

# Getting resized image info
height_2, width_2, color_channels_2 = image_2_resized.shape
print("Resized image 2 resolution is {}x{}".format(width_2, height_2))

# Saving resized image to the file
cv2.imwrite(images_path + "flower_2_resized.jpg", cv2.cvtColor(image_2_resized, cv2.COLOR_RGB2BGR))

# Increasing intensity of r channel for 33%
image_2_increased_intensity = image_2_resized.copy()
image_2_increased_intensity[:, :, 0] = image_2_increased_intensity[:, :, 0] * 1.34
plt.imshow(image_2_increased_intensity)
plt.show()

# Getting image color values at 242 row and 328 column
r, g, b = image_2_increased_intensity[281][388]
print(f'{r}, {g}, {b}')
# Out:
# Aspect ratio of image is: 1.5
# New image height is 546
# Resized image 2 resolution is 820x546
# 213, 85, 7
